# %%
import pandas as pd
import json
import numpy as np
import codecs

# %%
# Handle JSON conversions
class NpEncoder(json.JSONEncoder):
    def default(self, obj):
        if isinstance(obj, np.integer):
            return int(obj)
        if isinstance(obj, np.floating):
            return float(obj)
        if isinstance(obj, np.ndarray):
            return obj.tolist()
        if isinstance(obj, float) and np.isnan(obj):
          return None
        return super(NpEncoder, self).default(obj)

# %%
# !pip install ipdb

import ipdb
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting ipdb
#   Downloading ipdb-0.13.13-py3-none-any.whl (12 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipdb) (4.4.2)
# Requirement already satisfied: ipython>=7.31.1 in /usr/local/lib/python3.10/dist-packages (from ipdb) (7.34.0)
# Requirement already satisfied: tomli in /usr/local/lib/python3.10/dist-packages (from ipdb) (2.0.1)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.7.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (67.7.2)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (3.0.38)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.1.6)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (5.7.1)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (4.8.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (0.2.0)
# Collecting jedi>=0.16
#   Downloading jedi-0.18.2-py2.py3-none-any.whl (1.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 19.7 MB/s eta 0:00:00
# Requirement already satisfied: pygments in /usr/local/lib/python3.10/dist-packages (from ipython>=7.31.1->ipdb) (2.14.0)
# Requirement already satisfied: parso<0.9.0,>=0.8.0 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=7.31.1->ipdb) (0.8.3)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.10/dist-packages (from pexpect>4.3->ipython>=7.31.1->ipdb) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.31.1->ipdb) (0.2.6)
# Installing collected packages: jedi, ipdb
# Successfully installed ipdb-0.13.13 jedi-0.18.2

# %%
# Load the data into a pandas dataframe:
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# load the SG Coarse ONET Dataset
file = "/content/drive/MyDrive/MTECH IS Project/data/jobs_merge_with_soc2018_and_sg_coarse_df.csv"
course_df = pd.read_csv(file, sep=',')

# Remove the Unamed:  0 Column
course_df = course_df.drop(columns=course_df.columns[0])
course_df = course_df[['O*NET-SOC Code', 'Title', 'Job Zone', 'university', 'school', 'degree']]

course_df[course_df.notnull().all(1)].head(120)
# Out:
#     O*NET-SOC Code                                              Title  \
# 9       11-3012.00                   Administrative Services Managers
# 10      11-3012.00                   Administrative Services Managers
# 11      11-3012.00                   Administrative Services Managers
# 30      11-9013.00  Farmers, Ranchers, and Other Agricultural Mana...
# 31      11-9013.00  Farmers, Ranchers, and Other Agricultural Mana...
# ..             ...                                                ...
# 400     25-1041.00      Agricultural Sciences Teachers, Postsecondary
# 401     25-1041.00      Agricultural Sciences Teachers, Postsecondary
# 402     25-1041.00      Agricultural Sciences Teachers, Postsecondary
# 403     25-1041.00      Agricultural Sciences Teachers, Postsecondary
# 404     25-1041.00      Agricultural Sciences Teachers, Postsecondary
#
#      Job Zone                         university  \
# 9         3.0  Singapore Institute of Technology
# 10        3.0  Singapore Institute of Technology
# 11        3.0  Singapore Institute of Technology
# 30        4.0  Singapore Institute of Technology
# 31        4.0  Singapore Institute of Technology
# ..        ...                                ...
# 400       5.0   National University of Singapore
# 401       5.0   Nanyang Technological University
# 402       5.0   Nanyang Technological University
# 403       5.0   Nanyang Technological University
# 404       5.0   Nanyang Technological University
#
#                               school  \
# 9    DigiPen Institute of Technology
# 10   DigiPen Institute of Technology
# 11   DigiPen Institute of Technology
# 30   DigiPen Institute of Technology
# 31   DigiPen Institute of Technology
# ..                               ...
# 400           Faculty of Engineering
# 401           College of Engineering
# 402           College of Engineering
# 403           College of Engineering
# 404           College of Engineering
#
#                                                 degree
# 9    Bachelor of Fine Arts in Digital Arts & Animation
# 10   Bachelor of Science in Computer Science & Game...
# 11   Bachelor of Science in Computer Science in Rea...
# 30   Bachelor of Fine Arts in Digital Art and Anima...
# 31   Bachelor of Science in Computer Science and Ga...
# ..                                                 ...
# 400  Bachelor of Engineering (Industrial and System...
# 401                              Materials Engineering
# 402                             Mechanical Engineering
# 403            Mechanical Engineering and Economics **
# 404                                   Maritime Studies
#
# [120 rows x 6 columns]

# %%
# Load educational programs data
programs_file = "/content/drive/MyDrive/MTECH IS Project/data/course_graduate_employment/programs_raw.json"
program_infos_file = "/content/drive/MyDrive/MTECH IS Project/data/course_graduate_employment/program_infos.json"


# Opening JSON file
_programs_file = open(programs_file, mode='r', encoding='utf-8-sig')
_program_infos_file = open(program_infos_file, mode='r', encoding='utf-8-sig')
  
# returns JSON object as 
# a dictionary
programs = json.load(_programs_file)
program_infos = json.load(_program_infos_file)
  
# Key the arrays by ID
programs_by_id = { d['id']: d for d in programs }
programs_by_id_json = json.dumps(programs_by_id, cls=NpEncoder)

with open("programs.json", "w") as outfile:
    outfile.write(programs_by_id_json)

programs_infos_by_id = {}
for d in program_infos:
  id = f"{d['program_id']}_{d['year']}"
  d["id"] = id
  programs_infos_by_id[id] = d

programs_infos_by_id_json = json.dumps(programs_infos_by_id, cls=NpEncoder)

with open("program_trends.json", "w") as outfile:
    outfile.write(programs_infos_by_id_json)

# %%
# Load Salary data
file_s = "/content/drive/MyDrive/MTECH IS Project/data/onet_salary.csv"
salary_df = pd.read_csv(file_s, sep=',')

# %%
# Convert IDs to string
salary_df['isco_code'] = salary_df['isco_code'].apply(str)
salary_df['ssoc_code'] = salary_df['ssoc_code'].apply(str)

salary_df.head()
# Out:
#    Unnamed: 0 onetsoc_code             title  \
# 0           0   11-1011.00  Chief Executives
# 1           1   11-1011.00  Chief Executives
# 2           2   11-1011.00  Chief Executives
# 3           3   11-1011.00  Chief Executives
# 4           4   11-1011.00  Chief Executives
#
#                                          description isco_code ssoc_code  \
# 0  Determine and formulate policies and provide o...      1112     11121
# 1  Determine and formulate policies and provide o...      1112     11121
# 2  Determine and formulate policies and provide o...      1112     11121
# 3  Determine and formulate policies and provide o...      1112     11121
# 4  Determine and formulate policies and provide o...      1112     11121
#
#                         ssoc_job_title top_riasec riasec riasec_rank  \
# 0              Ambassador (government)          E  E,C,S       1,2,3
# 1                      Auditor general          E  E,C,S       1,2,3
# 2           Civil service commissioner          E  E,C,S       1,2,3
# 3  Commissioner of civil defence force          E  E,C,S       1,2,3
# 4       Commissioner of inland revenue          E  E,C,S       1,2,3
#
#    min_salary  max_salary
# 0        1800        5500
# 1        1800        7000
# 2           0           0
# 3           0           0
# 4           0           0

# %%
# Select columns
select_cols = ['onetsoc_code', 'isco_code', 'ssoc_code', 'ssoc_job_title', 'min_salary', 'max_salary']

# Aggregate SSOC codes
def apply_extraction(row):
  column_names = list(row.columns)
  count = len(row)
  result = [None] * count
  for index in range(count):
    current_row = row.iloc[index]
    result[index] = {name: getattr(current_row, name) for name in column_names}
  return result

salary_group_df = salary_df.groupby('ssoc_code')[select_cols].apply(apply_extraction).reset_index(name='jobs')

salary_group_df.head()
# Out:
#   ssoc_code                                               jobs
# 0     11110  [{'onetsoc_code': '11-1031.00', 'isco_code': '...
# 1     11121  [{'onetsoc_code': '11-1011.00', 'isco_code': '...
# 2     11122  [{'onetsoc_code': '11-1011.00', 'isco_code': '...
# 3     11140  [{'onetsoc_code': '11-1021.00', 'isco_code': '...
# 4     11150  [{'onetsoc_code': '11-1021.00', 'isco_code': '...

# %%
ssoc_columns = ['isco_code', 'ssoc_code', 'ssoc_job_title', 'min_salary', 'max_salary']
ssoc_jobs = {}

for index, row in salary_group_df.iterrows():
  count = len(row["jobs"])

  for i in range(count):
    job = row.jobs[i]
    id = f"{job['ssoc_code']}_{i}"
    ssoc_jobs[id] = {name: job[name] for name in ssoc_columns}
    ssoc_jobs[id]['id'] = id

    # Reassign property as occupation ID
    ssoc_jobs[id]["occupation_id"] = job['onetsoc_code']
    # ipdb.set_trace()


ssoc_json = json.dumps(ssoc_jobs, cls=NpEncoder)

with open("ssoc_jobs.json", "w") as outfile:
    outfile.write(ssoc_json)

# %%
# Aggregate by O*NET SOC codes
select_cols = ['min_salary', 'max_salary']

salary_c_df = salary_df.copy()
# Remove unrealistic small values
salary_c_df[select_cols] = salary_c_df[select_cols].mask(salary_c_df[select_cols] < 100)

onet_group_df = salary_c_df.groupby('onetsoc_code').agg({'min_salary': ['min'], 'max_salary': ['max']})

onet_group_df.head(20)
# Out:
#              min_salary max_salary
#                     min        max
# onetsoc_code
# 11-1011.00       1000.0    20000.0
# 11-1011.03       1000.0    20000.0
# 11-1021.00        480.0    20000.0
# 11-1031.00       1600.0     8500.0
# 11-2011.00       1800.0    15000.0
# 11-2021.00        700.0    19000.0
# 11-2022.00        700.0    19000.0
# 11-3021.00        800.0    20000.0
# 11-3031.00        480.0    14000.0
# 11-3031.01        480.0    14000.0
# 11-3031.03        480.0    14000.0
# 11-3051.00        800.0    18000.0
# 11-3051.01        800.0    18000.0
# 11-3051.02        800.0    18000.0
# 11-3051.03        800.0    18000.0
# 11-3051.04        800.0    18000.0
# 11-3051.06        800.0    18000.0
# 11-3061.00        480.0    15000.0
# 11-3071.00        480.0    50000.0
# 11-3071.04        480.0    50000.0

# %%
onet_group_df.iloc(0)[1]['min_salary']['min']

onet_group_df.iloc(0)[1]['min_salary']['min']
# Out:
# 1000.0

# %%
onet_salaries = {}

def convert_value(value):
  return None if np.isnan(value) else value

for index, row in onet_group_df.iterrows():
    onet_salaries[index] = {
        "id": index,
        'min_salary': convert_value(row['min_salary']['min']),
        'max_salary': convert_value(row['max_salary']['max'])
    }

onet_salaries_json = json.dumps(onet_salaries, cls=NpEncoder)

with open("onet_salaries.json", "w") as outfile:
    outfile.write(onet_salaries_json)
