# %%
# !pip install pandas sentence_transformers
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: pandas in /usr/local/lib/python3.9/dist-packages (1.5.3)
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 2.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: python-dateutil>=2.8.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: numpy>=1.20.3 in /usr/local/lib/python3.9/dist-packages (from pandas) (1.22.4)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.9/dist-packages (from pandas) (2022.7.1)
# Collecting transformers<5.0.0,>=4.6.0
#   Downloading transformers-4.28.1-py3-none-any.whl (7.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.0/7.0 MB 40.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (2.0.0+cu118)
# Requirement already satisfied: torchvision in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (0.15.1+cu118)
# Requirement already satisfied: scikit-learn in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (1.10.1)
# Requirement already satisfied: nltk in /usr/local/lib/python3.9/dist-packages (from sentence_transformers) (3.8.1)
# Collecting sentencepiece
#   Downloading sentencepiece-0.1.98-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.3/1.3 MB 14.1 MB/s eta 0:00:00
# Collecting huggingface-hub>=0.4.0
#   Downloading huggingface_hub-0.13.4-py3-none-any.whl (200 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 200.1/200.1 kB 10.8 MB/s eta 0:00:00
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.5.0)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (23.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.11.0)
# Requirement already satisfied: requests in /usr/local/lib/python3.9/dist-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.27.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.9/dist-packages (from python-dateutil>=2.8.1->pandas) (1.16.0)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (1.11.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: triton==2.0.0 in /usr/local/lib/python3.9/dist-packages (from torch>=1.6.0->sentence_transformers) (2.0.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (3.25.2)
# Requirement already satisfied: lit in /usr/local/lib/python3.9/dist-packages (from triton==2.0.0->torch>=1.6.0->sentence_transformers) (16.0.1)
# Requirement already satisfied: regex!=2019.12.17 in /usr/local/lib/python3.9/dist-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2022.10.31)
# Collecting tokenizers!=0.11.3,<0.14,>=0.11.1
#   Downloading tokenizers-0.13.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (7.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.8/7.8 MB 40.3 MB/s eta 0:00:00
# Requirement already satisfied: joblib in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (1.2.0)
# Requirement already satisfied: click in /usr/local/lib/python3.9/dist-packages (from nltk->sentence_transformers) (8.1.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /usr/local/lib/python3.9/dist-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /usr/local/lib/python3.9/dist-packages (from torchvision->sentence_transformers) (8.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.9/dist-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.2)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.9/dist-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: mpmath>=0.19 in /usr/local/lib/python3.9/dist-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
#   Building wheel for sentence_transformers (setup.py) ... done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125942 sha256=a4aae8edd6337434a4469cb42e428106999790095399d383a929c85d9daae516
#   Stored in directory: /root/.cache/pip/wheels/71/67/06/162a3760c40d74dd40bc855d527008d26341c2b0ecf3e8e11f
# Successfully built sentence_transformers
# Installing collected packages: tokenizers, sentencepiece, huggingface-hub, transformers, sentence_transformers
# Successfully installed huggingface-hub-0.13.4 sentence_transformers-2.2.2 sentencepiece-0.1.98 tokenizers-0.13.3 transformers-4.28.1

# %%
import numpy as np
import pandas as pd
import re
import json
from scipy import spatial
from sentence_transformers import SentenceTransformer

# %%
# Files
occupation_data_file = "https://www.onetcenter.org/dl_files/database/db_27_2_text/Occupation%20Data.txt"
task_statements_file = "https://www.onetcenter.org/dl_files/database/db_27_2_text/Task%20Statements.txt"

# %%
# Loading the Occupational dataset
occupation_data = pd.read_csv(occupation_data_file, sep='\t')

index_col = "O*NET-SOC Code"

occupation_data = occupation_data.set_index(index_col)

occupation_data.head()
# Out:
#                                               Title  \
# O*NET-SOC Code
# 11-1011.00                         Chief Executives
# 11-1011.03            Chief Sustainability Officers
# 11-1021.00          General and Operations Managers
# 11-1031.00                              Legislators
# 11-2011.00      Advertising and Promotions Managers
#
#                                                       Description
# O*NET-SOC Code
# 11-1011.00      Determine and formulate policies and provide o...
# 11-1011.03      Communicate and coordinate with management, sh...
# 11-1021.00      Plan, direct, or coordinate the operations of ...
# 11-1031.00      Develop, introduce, or enact laws and statutes...
# 11-2011.00      Plan, direct, or coordinate advertising polici...

# %%
# Loading the Tasks dataset
task_data = pd.read_csv(task_statements_file, sep='\t')

task_data = task_data.set_index(index_col)

task_data.head()
# Out:
#                 Task ID                                               Task  \
# O*NET-SOC Code
# 11-1011.00         8823  Direct or coordinate an organization's financi...
# 11-1011.00         8831  Appoint department heads or managers and assig...
# 11-1011.00         8825  Analyze operations to evaluate performance of ...
# 11-1011.00         8826  Direct, plan, or implement policies, objective...
# 11-1011.00         8827  Prepare budgets for approval, including those ...
#
#                Task Type  Incumbents Responding     Date Domain Source
# O*NET-SOC Code
# 11-1011.00          Core                   87.0  07/2014     Incumbent
# 11-1011.00          Core                   87.0  07/2014     Incumbent
# 11-1011.00          Core                   87.0  07/2014     Incumbent
# 11-1011.00          Core                   87.0  07/2014     Incumbent
# 11-1011.00          Core                   87.0  07/2014     Incumbent

# %%
# Aggregate job description
group_task_df = task_data[['Task']]\
  .groupby(["O*NET-SOC Code"])['Task']\
  .apply(lambda x: '\t'.join(x)).reset_index()

group_task_df.head()
# Out:
#   O*NET-SOC Code                                               Task
# 0     11-1011.00  Direct or coordinate an organization's financi...
# 1     11-1011.03  Monitor and evaluate effectiveness of sustaina...
# 2     11-1021.00  Review financial statements, sales or activity...
# 3     11-1031.00  Analyze and understand the local and national ...
# 4     11-2011.00  Plan and prepare advertising and promotional m...

# %%
# Merge with occupational data table
merge_df = occupation_data.merge(
  group_task_df, on="O*NET-SOC Code", suffixes=("_df1", "_df2"), how='inner'
)

merge_df = merge_df.set_index(index_col)

merge_df["description_task"] = merge_df["Description"] + "\t" + merge_df["Task"]

merge_df.head()
# Out:
#                                               Title  \
# O*NET-SOC Code
# 11-1011.00                         Chief Executives
# 11-1011.03            Chief Sustainability Officers
# 11-1021.00          General and Operations Managers
# 11-1031.00                              Legislators
# 11-2011.00      Advertising and Promotions Managers
#
#                                                       Description  \
# O*NET-SOC Code
# 11-1011.00      Determine and formulate policies and provide o...
# 11-1011.03      Communicate and coordinate with management, sh...
# 11-1021.00      Plan, direct, or coordinate the operations of ...
# 11-1031.00      Develop, introduce, or enact laws and statutes...
# 11-2011.00      Plan, direct, or coordinate advertising polici...
#
#                                                              Task  \
# O*NET-SOC Code
# 11-1011.00      Direct or coordinate an organization's financi...
# 11-1011.03      Monitor and evaluate effectiveness of sustaina...
# 11-1021.00      Review financial statements, sales or activity...
# 11-1031.00      Analyze and understand the local and national ...
# 11-2011.00      Plan and prepare advertising and promotional m...
#
#                                                  description_task
# O*NET-SOC Code
# 11-1011.00      Determine and formulate policies and provide o...
# 11-1011.03      Communicate and coordinate with management, sh...
# 11-1021.00      Plan, direct, or coordinate the operations of ...
# 11-1031.00      Develop, introduce, or enact laws and statutes...
# 11-2011.00      Plan, direct, or coordinate advertising polici...

# %%
merge_df.describe()
# Out:
#                    Title                                        Description  \
# count                923                                                923
# unique               923                                                923
# top     Chief Executives  Determine and formulate policies and provide o...
# freq                   1                                                  1
#
#                                                      Task  \
# count                                                 923
# unique                                                923
# top     Direct or coordinate an organization's financi...
# freq                                                    1
#
#                                          description_task
# count                                                 923
# unique                                                923
# top     Determine and formulate policies and provide o...
# freq                                                    1

# %% [markdown]
# Text Processing

# %%
model = SentenceTransformer('sentence-transformers/all-mpnet-base-v2')
# Out:
# Downloading (…)a8e1d/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)0bca8e1d/config.json:   0%|          | 0.00/571 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)e1d/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/438M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/239 [00:00<?, ?B/s]
# Downloading (…)a8e1d/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/363 [00:00<?, ?B/s]
# Downloading (…)8e1d/train_script.py:   0%|          | 0.00/13.1k [00:00<?, ?B/s]
# Downloading (…)b20bca8e1d/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)bca8e1d/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]

# %%
task_embeddings = model.encode(merge_df["description_task"])

# %%
task_embeddings.shape
# Out:
# (923, 768)

# %%
task_embeddings
# Out:
# array([[ 0.05364482,  0.01825294,  0.00836201, ..., -0.00818568,
#          0.03841463, -0.0037288 ],
#        [ 0.05310498,  0.06315918,  0.00045989, ..., -0.00501814,
#          0.02057329, -0.00680427],
#        [ 0.03038887,  0.00030764, -0.00270253, ...,  0.00073381,
#          0.01919656, -0.01241072],
#        ...,
#        [-0.00132103, -0.00754632,  0.00295144, ...,  0.01046922,
#         -0.01817417, -0.01741959],
#        [ 0.04147436,  0.0771044 ,  0.00296297, ..., -0.03907046,
#          0.01063881,  0.01055883],
#        [-0.02435871,  0.01742864, -0.01280583, ..., -0.00957355,
#         -0.02452322, -0.02681528]], dtype=float32)

# %%
# Assign embeddings to occupation
merge_df["embeddings"] = np.ndarray.tolist(task_embeddings)
merge_df.head()
# Out:
#                                               Title  \
# O*NET-SOC Code
# 11-1011.00                         Chief Executives
# 11-1011.03            Chief Sustainability Officers
# 11-1021.00          General and Operations Managers
# 11-1031.00                              Legislators
# 11-2011.00      Advertising and Promotions Managers
#
#                                                       Description  \
# O*NET-SOC Code
# 11-1011.00      Determine and formulate policies and provide o...
# 11-1011.03      Communicate and coordinate with management, sh...
# 11-1021.00      Plan, direct, or coordinate the operations of ...
# 11-1031.00      Develop, introduce, or enact laws and statutes...
# 11-2011.00      Plan, direct, or coordinate advertising polici...
#
#                                                              Task  \
# O*NET-SOC Code
# 11-1011.00      Direct or coordinate an organization's financi...
# 11-1011.03      Monitor and evaluate effectiveness of sustaina...
# 11-1021.00      Review financial statements, sales or activity...
# 11-1031.00      Analyze and understand the local and national ...
# 11-2011.00      Plan and prepare advertising and promotional m...
#
#                                                  description_task  \
# O*NET-SOC Code
# 11-1011.00      Determine and formulate policies and provide o...
# 11-1011.03      Communicate and coordinate with management, sh...
# 11-1021.00      Plan, direct, or coordinate the operations of ...
# 11-1031.00      Develop, introduce, or enact laws and statutes...
# 11-2011.00      Plan, direct, or coordinate advertising polici...
#
#                                                        embeddings
# O*NET-SOC Code
# 11-1011.00      [0.0536448210477829, 0.018252937123179436, 0.0...
# 11-1011.03      [0.053104981780052185, 0.06315918266773224, 0....
# 11-1021.00      [0.03038887307047844, 0.00030763985705561936, ...
# 11-1031.00      [0.02162821590900421, 0.05060312896966934, 0.0...
# 11-2011.00      [0.07993657886981964, 0.03238765150308609, 0.0...

# %%
merge_df.to_csv("jobs_tasks.csv")

# %% [markdown]
# Text Similarity via Cosine Similarity

# %%
from sklearn.metrics.pairwise import cosine_similarity

# %%
df = merge_df.copy()

def calc_similarity(input):
    data = df.copy()
    input_vector = model.encode(input)
    s = data['embeddings'].apply(lambda x: 1 - spatial.distance.cosine(x, input_vector))
    data = data.assign(similarity = s)
    return(data.sort_values('similarity',ascending=False))

# %%
sample_input_text = "I like math and into tasting different cuisines"

# %%
results = calc_similarity(sample_input_text)
results.head(20)
# Out:
#                                                             Title  \
# O*NET-SOC Code
# 35-2013.00                               Cooks, Private Household
# 19-1012.00                      Food Scientists and Technologists
# 35-1011.00                                   Chefs and Head Cooks
# 19-4013.00                               Food Science Technicians
# 15-2021.00                                         Mathematicians
# 35-2015.00                                     Cooks, Short Order
# 51-3092.00                                       Food Batchmakers
# 35-2011.00                                       Cooks, Fast Food
# 35-2014.00                                      Cooks, Restaurant
# 35-2021.00                               Food Preparation Workers
# 51-3011.00                                                 Bakers
# 35-3031.00                                 Waiters and Waitresses
# 19-2011.00                                            Astronomers
# 19-3092.00                                            Geographers
# 11-9051.00                                  Food Service Managers
# 35-2012.00                       Cooks, Institution and Cafeteria
# 35-9011.00      Dining Room and Cafeteria Attendants and Barte...
# 35-3023.00                          Fast Food and Counter Workers
# 51-3093.00             Food Cooking Machine Operators and Tenders
# 35-9031.00      Hosts and Hostesses, Restaurant, Lounge, and C...
#
#                                                       Description  \
# O*NET-SOC Code
# 35-2013.00      Prepare meals in private homes. Includes perso...
# 19-1012.00      Use chemistry, microbiology, engineering, and ...
# 35-1011.00      Direct and may participate in the preparation,...
# 19-4013.00      Work with food scientists or technologists to ...
# 15-2021.00      Conduct research in fundamental mathematics or...
# 35-2015.00      Prepare and cook to order a variety of foods t...
# 51-3092.00      Set up and operate equipment that mixes or ble...
# 35-2011.00      Prepare and cook food in a fast food restauran...
# 35-2014.00      Prepare, season, and cook dishes such as soups...
# 35-2021.00      Perform a variety of food preparation duties o...
# 51-3011.00      Mix and bake ingredients to produce breads, ro...
# 35-3031.00      Take orders and serve food and beverages to pa...
# 19-2011.00      Observe, research, and interpret astronomical ...
# 19-3092.00      Study the nature and use of areas of the Earth...
# 11-9051.00      Plan, direct, or coordinate activities of an o...
# 35-2012.00      Prepare and cook large quantities of food for ...
# 35-9011.00      Facilitate food service. Clean tables; remove ...
# 35-3023.00      Perform duties such as taking orders and servi...
# 51-3093.00      Operate or tend cooking equipment, such as ste...
# 35-9031.00      Welcome patrons, seat them at tables or in lou...
#
#                                                              Task  \
# O*NET-SOC Code
# 35-2013.00      Plan menus according to employers' needs and d...
# 19-1012.00      Inspect food processing areas to ensure compli...
# 35-1011.00      Monitor sanitation practices to ensure that em...
# 19-4013.00      Record or compile test results or prepare grap...
# 15-2021.00      Address the relationships of quantities, magni...
# 35-2015.00      Clean food preparation equipment, work areas, ...
# 51-3092.00      Record production and test data for each food ...
# 35-2011.00      Order and take delivery of supplies.\tCook the...
# 35-2014.00      Inspect and clean food preparation areas, such...
# 35-2021.00      Clean and sanitize work areas, equipment, uten...
# 51-3011.00      Check products for quality, and identify damag...
# 35-3031.00      Take orders from patrons for food or beverages...
# 19-2011.00      Mentor graduate students and junior colleagues...
# 19-3092.00      Create and modify maps, graphs, or diagrams, u...
# 11-9051.00      Keep records required by government agencies r...
# 35-2012.00      Monitor and record food temperatures to ensure...
# 35-9011.00      Run cash registers.\tServe ice water, coffee, ...
# 35-3023.00      Communicate with customers regarding orders, c...
# 51-3093.00      Clean, wash, and sterilize equipment and cooki...
# 35-9031.00      Provide guests with menus.\tAssign patrons to ...
#
#                                                  description_task  \
# O*NET-SOC Code
# 35-2013.00      Prepare meals in private homes. Includes perso...
# 19-1012.00      Use chemistry, microbiology, engineering, and ...
# 35-1011.00      Direct and may participate in the preparation,...
# 19-4013.00      Work with food scientists or technologists to ...
# 15-2021.00      Conduct research in fundamental mathematics or...
# 35-2015.00      Prepare and cook to order a variety of foods t...
# 51-3092.00      Set up and operate equipment that mixes or ble...
# 35-2011.00      Prepare and cook food in a fast food restauran...
# 35-2014.00      Prepare, season, and cook dishes such as soups...
# 35-2021.00      Perform a variety of food preparation duties o...
# 51-3011.00      Mix and bake ingredients to produce breads, ro...
# 35-3031.00      Take orders and serve food and beverages to pa...
# 19-2011.00      Observe, research, and interpret astronomical ...
# 19-3092.00      Study the nature and use of areas of the Earth...
# 11-9051.00      Plan, direct, or coordinate activities of an o...
# 35-2012.00      Prepare and cook large quantities of food for ...
# 35-9011.00      Facilitate food service. Clean tables; remove ...
# 35-3023.00      Perform duties such as taking orders and servi...
# 51-3093.00      Operate or tend cooking equipment, such as ste...
# 35-9031.00      Welcome patrons, seat them at tables or in lou...
#
#                                                        embeddings  similarity
# O*NET-SOC Code
# 35-2013.00      [0.005730997305363417, 0.022486571222543716, -...    0.306955
# 19-1012.00      [0.054701369255781174, 0.0664542019367218, -0....    0.300826
# 35-1011.00      [0.026355532929301262, 0.032496266067028046, -...    0.267080
# 19-4013.00      [0.03496571257710457, 0.004672635812312365, -0...    0.265807
# 15-2021.00      [-0.0152164651080966, 0.0656314417719841, 4.13...    0.265395
# 35-2015.00      [0.006050362251698971, -0.0005959015106782317,...    0.262124
# 51-3092.00      [-0.016138162463903427, -0.030569136142730713,...    0.261882
# 35-2011.00      [0.012925593182444572, 0.0021542359609156847, ...    0.259068
# 35-2014.00      [0.023434465751051903, 0.01888412982225418, -0...    0.254589
# 35-2021.00      [0.023771002888679504, 0.01435038074851036, -0...    0.248258
# 51-3011.00      [-0.010792399756610394, -0.03056647628545761, ...    0.232127
# 35-3031.00      [0.03896818682551384, -0.0067965309135615826, ...    0.230502
# 19-2011.00      [0.09218519181013107, 0.026495572179555893, -0...    0.226126
# 19-3092.00      [0.053837742656469345, 0.04080617055296898, -0...    0.224487
# 11-9051.00      [0.032652709633111954, 0.05972559377551079, -0...    0.222867
# 35-2012.00      [0.016780836507678032, 0.05299622565507889, 3....    0.218009
# 35-9011.00      [0.02729017660021782, 0.015982147306203842, -0...    0.216602
# 35-3023.00      [0.02088203653693199, 0.0031096881721168756, -...    0.214948
# 51-3093.00      [-0.03033737652003765, -0.022104104980826378, ...    0.206243
# 35-9031.00      [0.037803299725055695, 0.007089233957231045, -...    0.204439

# %%
vecs = merge_df[['embeddings']].copy()
vecs = vecs.reset_index()
vecs = vecs.rename(columns={index_col: "id"})
vecs.head()
# Out:
#            id                                         embeddings
# 0  11-1011.00  [0.0536448210477829, 0.018252937123179436, 0.0...
# 1  11-1011.03  [0.053104981780052185, 0.06315918266773224, 0....
# 2  11-1021.00  [0.03038887307047844, 0.00030763985705561936, ...
# 3  11-1031.00  [0.02162821590900421, 0.05060312896966934, 0.0...
# 4  11-2011.00  [0.07993657886981964, 0.03238765150308609, 0.0...

# %%
vecs.to_pickle("./task_embeddings.pkl")

# %%
emb_df = pd.read_pickle("./task_embeddings.pkl")

emb_df.head()
# Out:
#            id                                         embeddings
# 0  11-1011.00  [0.0536448210477829, 0.018252937123179436, 0.0...
# 1  11-1011.03  [0.053104981780052185, 0.06315918266773224, 0....
# 2  11-1021.00  [0.03038887307047844, 0.00030763985705561936, ...
# 3  11-1031.00  [0.02162821590900421, 0.05060312896966934, 0.0...
# 4  11-2011.00  [0.07993657886981964, 0.03238765150308609, 0.0...

# %%
task_embeddings = model.encode(merge_df["description_task"])

# %%
embeddings_df = pd.DataFrame(task_embeddings)

merge_embeddings_df = group_task_df[[index_col]].join(embeddings_df).set_index(index_col)

merge_embeddings_df.head()
# Out:
#                      0         1         2         3         4         5    \
# O*NET-SOC Code
# 11-1011.00      0.053645  0.018253  0.008362  0.020310 -0.026004  0.045552
# 11-1011.03      0.053105  0.063159  0.000460  0.009874 -0.005874  0.025072
# 11-1021.00      0.030389  0.000308 -0.002703 -0.004188 -0.019920  0.033918
# 11-1031.00      0.021628  0.050603  0.011500  0.020515 -0.083787  0.025022
# 11-2011.00      0.079937  0.032388  0.005315 -0.046845 -0.004993  0.007684
#
#                      6         7         8         9    ...       758  \
# O*NET-SOC Code                                          ...
# 11-1011.00     -0.042385 -0.018059  0.019062 -0.013607  ...  0.024042
# 11-1011.03     -0.031806 -0.005352 -0.052735 -0.021316  ...  0.001337
# 11-1021.00      0.028961 -0.015089 -0.026181 -0.011414  ...  0.001564
# 11-1031.00     -0.031809 -0.000512  0.007156 -0.015567  ...  0.048320
# 11-2011.00     -0.016015 -0.032601 -0.011916 -0.041920  ...  0.021450
#
#                      759       760       761       762       763       764  \
# O*NET-SOC Code
# 11-1011.00     -0.031567 -0.059860  0.035682 -0.049713 -0.066396 -0.006808
# 11-1011.03     -0.032829 -0.072195  0.001321 -0.015946 -0.054686  0.010460
# 11-1021.00     -0.036881 -0.080305  0.008594 -0.052148 -0.066299 -0.007575
# 11-1031.00     -0.038064 -0.040545  0.034387 -0.043746 -0.035286 -0.030910
# 11-2011.00     -0.027315 -0.048459 -0.004725 -0.057103 -0.027643 -0.035003
#
#                      765       766       767
# O*NET-SOC Code
# 11-1011.00     -0.008186  0.038415 -0.003729
# 11-1011.03     -0.005018  0.020573 -0.006804
# 11-1021.00      0.000734  0.019197 -0.012411
# 11-1031.00     -0.009832  0.048270 -0.013265
# 11-2011.00      0.011107 -0.001153 -0.008362
#
# [5 rows x 768 columns]

# %%
# Calculate item-to-item cosine similarity
cs = cosine_similarity(merge_embeddings_df)
print(cs)
# Out:
# [[0.99999994 0.59117174 0.8439366  ... 0.5616852  0.41994438 0.42809284]
#  [0.59117174 1.0000002  0.6130444  ... 0.39549705 0.46762455 0.36703587]
#  [0.8439366  0.6130444  0.99999964 ... 0.53880125 0.55187166 0.560198  ]
#  ...
#  [0.5616852  0.39549705 0.53880125 ... 1.0000005  0.5649844  0.70752424]
#  [0.41994438 0.46762455 0.55187166 ... 0.5649844  1.0000002  0.70315635]
#  [0.42809284 0.36703587 0.560198   ... 0.70752424 0.70315635 1.0000005 ]]

# %%
cs_df = pd.DataFrame(cs, index=merge_embeddings_df.index, columns=merge_embeddings_df.index)
cs_df.to_csv('./similarity.csv')
