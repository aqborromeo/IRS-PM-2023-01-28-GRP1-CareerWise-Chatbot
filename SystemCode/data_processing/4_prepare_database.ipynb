# %%
import numpy as np
import pandas as pd
import json

# %%
# Import results from `jobs_merge.csv` file
id_col = 'O*NET-SOC Code'

jobs_merge = pd.read_csv("jobs_merge.csv", sep=',').set_index(id_col)
jobs_tasks =  pd.read_csv("jobs_tasks.csv", sep=',').set_index(id_col)

jobs_merge.head()

new_merge_df = jobs_merge.merge(
  jobs_tasks[['Task']], on="O*NET-SOC Code", suffixes=("_df1", "_df2"), how='inner'
)
# # Remove unnamed columns, reset indexes
new_merge_df = new_merge_df.loc[:, ~new_merge_df.columns.str.contains('^Unnamed')].reset_index().reset_index()

# %%
new_merge_df.head()
# Out:
#    index O*NET-SOC Code                                Title  \
# 0      0     11-1011.00                     Chief Executives
# 1      1     11-1011.03        Chief Sustainability Officers
# 2      2     11-1021.00      General and Operations Managers
# 3      3     11-1031.00                          Legislators
# 4      4     11-2011.00  Advertising and Promotions Managers
#
#                                          Description  Job Zone     Date  \
# 0  Determine and formulate policies and provide o...       5.0  07/2014
# 1  Communicate and coordinate with management, sh...       5.0  08/2021
# 2  Plan, direct, or coordinate the operations of ...       4.0  07/2015
# 3  Develop, introduce, or enact laws and statutes...       4.0  06/2008
# 4  Plan, direct, or coordinate advertising polici...       4.0  08/2018
#
#   Domain Source  required_level_of_education_1  required_level_of_education_2  \
# 0       Analyst                           0.00                           0.00
# 1       Analyst                           0.00                           0.00
# 2       Analyst                           0.00                          15.20
# 3       Analyst                            NaN                            NaN
# 4       Analyst                           6.16                           9.82
#
#    required_level_of_education_3  ...  context_duration_of_typical_work_week  \
# 0                            0.0  ...                                   2.89
# 1                            0.0  ...                                   2.74
# 2                            9.0  ...                                   2.86
# 3                            NaN  ...                                    NaN
# 4                            0.0  ...                                   2.48
#
#                          career_cluster        career_pathway  \
# 0  Business Management & Administration    General Management
# 1  Business Management & Administration    General Management
# 2  Business Management & Administration    General Management
# 3    Government & Public Administration            Governance
# 4                             Marketing  Marketing Management
#
#    education_median  education_mode  education_diff  experience_median  \
# 0               8.0             8.0             0.0                9.0
# 1               8.0             8.0             0.0                8.0
# 2               5.0             6.0             1.0                8.0
# 3               NaN             NaN             NaN                NaN
# 4               6.0             6.0             0.0                8.0
#
#    experience_mode  experience_diff  \
# 0             11.0              2.0
# 1              8.0              0.0
# 2              8.0              0.0
# 3              NaN              NaN
# 4              8.0              0.0
#
#                                                 Task
# 0  Direct or coordinate an organization's financi...
# 1  Monitor and evaluate effectiveness of sustaina...
# 2  Review financial statements, sales or activity...
# 3  Analyze and understand the local and national ...
# 4  Plan and prepare advertising and promotional m...
#
# [5 rows x 218 columns]

# %%
# Output data with selected columns
selected_df = new_merge_df[[
    'O*NET-SOC Code',
    'index',
    'Title',
    'Description',
    'Task',
    'Job Zone',

    # Education
    'education_mode',
    'education_median',
    # Experience
    'experience_mode',
    'experience_median',

    # Style
    'style_stress_tolerance',
    'style_achievement_effort',
    'style_social_orientation',
    'style_independence',
    'style_innovation',
    # Context
    'context_duration_of_typical_work_week',
    'context_outdoors_exposed_to_weather',
    'context_deal_with_unpleasant_or_angry_people',
    'context_exposed_to_hazardous_conditions'
]]

selected_df = selected_df.rename(columns={
    'O*NET-SOC Code': 'id',
    'Title': 'title',
    'Description': 'description',
    'Task': 'task',
    'Job Zone': 'job_zone'
  })

# %%
selected_df = selected_df.set_index('id')
selected_df.head()
# Out:
#             index                                title  \
# id
# 11-1011.00      0                     Chief Executives
# 11-1011.03      1        Chief Sustainability Officers
# 11-1021.00      2      General and Operations Managers
# 11-1031.00      3                          Legislators
# 11-2011.00      4  Advertising and Promotions Managers
#
#                                                   description  \
# id
# 11-1011.00  Determine and formulate policies and provide o...
# 11-1011.03  Communicate and coordinate with management, sh...
# 11-1021.00  Plan, direct, or coordinate the operations of ...
# 11-1031.00  Develop, introduce, or enact laws and statutes...
# 11-2011.00  Plan, direct, or coordinate advertising polici...
#
#                                                          task  job_zone  \
# id
# 11-1011.00  Direct or coordinate an organization's financi...       5.0
# 11-1011.03  Monitor and evaluate effectiveness of sustaina...       5.0
# 11-1021.00  Review financial statements, sales or activity...       4.0
# 11-1031.00  Analyze and understand the local and national ...       4.0
# 11-2011.00  Plan and prepare advertising and promotional m...       4.0
#
#             education_mode  education_median  experience_mode  \
# id
# 11-1011.00             8.0               8.0             11.0
# 11-1011.03             8.0               8.0              8.0
# 11-1021.00             6.0               5.0              8.0
# 11-1031.00             NaN               NaN              NaN
# 11-2011.00             6.0               6.0              8.0
#
#             experience_median  style_stress_tolerance  \
# id
# 11-1011.00                9.0                    4.75
# 11-1011.03                8.0                    3.96
# 11-1021.00                8.0                    4.33
# 11-1031.00                NaN                     NaN
# 11-2011.00                8.0                    4.35
#
#             style_achievement_effort  style_social_orientation  \
# id
# 11-1011.00                      4.55                      3.67
# 11-1011.03                      4.19                      3.78
# 11-1021.00                      4.18                      3.57
# 11-1031.00                       NaN                       NaN
# 11-2011.00                      4.10                      3.70
#
#             style_independence  style_innovation  \
# id
# 11-1011.00                4.54              4.27
# 11-1011.03                4.26              4.48
# 11-1021.00                3.99              3.65
# 11-1031.00                 NaN               NaN
# 11-2011.00                4.04              3.99
#
#             context_duration_of_typical_work_week  \
# id
# 11-1011.00                                   2.89
# 11-1011.03                                   2.74
# 11-1021.00                                   2.86
# 11-1031.00                                    NaN
# 11-2011.00                                   2.48
#
#             context_outdoors_exposed_to_weather  \
# id
# 11-1011.00                                 2.21
# 11-1011.03                                 2.23
# 11-1021.00                                 1.96
# 11-1031.00                                  NaN
# 11-2011.00                                 2.46
#
#             context_deal_with_unpleasant_or_angry_people  \
# id
# 11-1011.00                                          3.57
# 11-1011.03                                          2.41
# 11-1021.00                                          3.44
# 11-1031.00                                           NaN
# 11-2011.00                                          2.92
#
#             context_exposed_to_hazardous_conditions
# id
# 11-1011.00                                     1.65
# 11-1011.03                                     1.37
# 11-1021.00                                     1.64
# 11-1031.00                                      NaN
# 11-2011.00                                     1.06

# %%
selected_df_json = selected_df.to_json(orient="index")

print(selected_df_json)
# Out:
# Output hidden; open in https://colab.research.google.com to view.

# %%
with open("occupations.json", "w") as outfile:
    outfile.write(selected_df_json)

# %% [markdown]
# **Career Pathways**

# %%
cosim_df = pd.read_csv("similarity.csv", sep=',')

# %%
# Required columns to decide path direction
required_cols = ['Title', 'Job Zone', 'education_median', 'education_mode', 'experience_median',	'experience_mode', 'career_cluster', 'career_pathway']

# %%
# Insert required columns for knowledge graph
sim_final_df = cosim_df.copy()

# sim_final_df = sim_final_df.set_index(id_col)

for index in range(len(required_cols)):
  insert_index = index + 1
  sim_final_df.insert(insert_index, required_cols[index], new_merge_df[required_cols[index]])

sim_final_df.head()

required_cols_len = len(required_cols)

# %%
sim_final_df = sim_final_df.set_index(id_col)

# %%
sim_final_df.head()
# Out:
#                                               Title  Job Zone  \
# O*NET-SOC Code
# 11-1011.00                         Chief Executives       5.0
# 11-1011.03            Chief Sustainability Officers       5.0
# 11-1021.00          General and Operations Managers       4.0
# 11-1031.00                              Legislators       4.0
# 11-2011.00      Advertising and Promotions Managers       4.0
#
#                 education_median  education_mode  experience_median  \
# O*NET-SOC Code
# 11-1011.00                   8.0             8.0                9.0
# 11-1011.03                   8.0             8.0                8.0
# 11-1021.00                   5.0             6.0                8.0
# 11-1031.00                   NaN             NaN                NaN
# 11-2011.00                   6.0             6.0                8.0
#
#                 experience_mode                        career_cluster  \
# O*NET-SOC Code
# 11-1011.00                 11.0  Business Management & Administration
# 11-1011.03                  8.0  Business Management & Administration
# 11-1021.00                  8.0  Business Management & Administration
# 11-1031.00                  NaN    Government & Public Administration
# 11-2011.00                  8.0                             Marketing
#
#                       career_pathway  11-1011.00  11-1011.03  ...  53-7062.00  \
# O*NET-SOC Code                                                ...
# 11-1011.00        General Management    1.000000    0.591172  ...    0.403639
# 11-1011.03        General Management    0.591172    1.000000  ...    0.339362
# 11-1021.00        General Management    0.843937    0.613044  ...    0.556488
# 11-1031.00                Governance    0.735055    0.454880  ...    0.411206
# 11-2011.00      Marketing Management    0.675352    0.507233  ...    0.350519
#
#                 53-7062.04  53-7063.00  53-7064.00  53-7065.00  53-7071.00  \
# O*NET-SOC Code
# 11-1011.00        0.404391    0.516145    0.361697    0.599789    0.555423
# 11-1011.03        0.530367    0.408795    0.326051    0.443778    0.437448
# 11-1021.00        0.523341    0.608168    0.536180    0.761739    0.602178
# 11-1031.00        0.391405    0.454076    0.348042    0.464771    0.475191
# 11-2011.00        0.362442    0.409167    0.356931    0.533211    0.427089
#
#                 53-7072.00  53-7073.00  53-7081.00  53-7121.00
# O*NET-SOC Code
# 11-1011.00        0.510832    0.561685    0.419944    0.428093
# 11-1011.03        0.395737    0.395497    0.467625    0.367036
# 11-1021.00        0.587606    0.538801    0.551872    0.560198
# 11-1031.00        0.440169    0.471908    0.390212    0.387859
# 11-2011.00        0.411167    0.427121    0.414391    0.367862
#
# [5 rows x 931 columns]

# %% [markdown]
# **Knowledge Graph**

# %%
def filter_valid_path(row):
  row_id = row.name
  evaluation_cols = row.iloc[required_cols_len:]
  matches = evaluation_cols.gt(0.6)
  matches = matches.index[matches].tolist()
  matches.remove(row_id)

  comparison_col = 'experience_median'
  current_row_value = row[comparison_col]
  category_col = 'career_pathway'
  current_row_category_value = row[category_col]

  filtered = sim_final_df.loc[matches]
  filtered = filtered[(filtered[comparison_col] > current_row_value) & (filtered[category_col] == current_row_category_value)]
  return filtered.index.tolist()
  
promotions = sim_final_df.apply(filter_valid_path, axis=1)

promotions.head()
# Out:
# O*NET-SOC Code
# 11-1011.00                            [11-3031.03]
# 11-1011.03                                      []
# 11-1021.00    [11-1011.00, 11-3031.03, 11-3071.04]
# 11-1031.00                                      []
# 11-2011.00                            [11-2021.00]
# dtype: object

# %%
promotions_dict = {}
comparison_col = 'experience_median'

for source_id, row in promotions.iteritems():
  if row:
    for target_id in row:
      source_item = selected_df.loc[source_id]
      target_item = selected_df.loc[target_id]
      relation_id = f"{source_id}__{target_id}"
      promotions_dict[relation_id] = {
          "id": relation_id,
          "source_id": source_id,
          "target_id": target_id,
          "difference": target_item[comparison_col] - source_item[comparison_col]
      }
      print(f"({source_id}: {source_item['title']} [{source_item[comparison_col]}]) -[upskill]-> ({target_id}: {target_item['title']} [{target_item[comparison_col]}])")

promotions_json = json.dumps(promotions_dict)

with open("relations.json", "w") as outfile:
    outfile.write(promotions_json)
# Out:
# <ipython-input-32-765e7b03f23f>:4: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   for source_id, row in promotions.iteritems():
# Streaming output truncated to the last 5000 lines.
# (21-1021.00: Child, Family, and School Social Workers [6.0]) -[upskill]-> (21-1094.00: Community Health Workers [7.0])
# (21-1022.00: Healthcare Social Workers [6.0]) -[upskill]-> (11-9151.00: Social and Community Service Managers [8.0])
# (21-1022.00: Healthcare Social Workers [6.0]) -[upskill]-> (21-1094.00: Community Health Workers [7.0])
# (21-1023.00: Mental Health and Substance Abuse Social Workers [7.0]) -[upskill]-> (21-1011.00: Substance Abuse and Behavioral Disorder Counselors [8.0])
# (21-1091.00: Health Education Specialists [6.0]) -[upskill]-> (11-9151.00: Social and Community Service Managers [8.0])
# (21-1091.00: Health Education Specialists [6.0]) -[upskill]-> (21-1094.00: Community Health Workers [7.0])
# (21-1092.00: Probation Officers and Correctional Treatment Specialists [6.0]) -[upskill]-> (33-1011.00: First-Line Supervisors of Correctional Officers [7.0])
# (21-1093.00: Social and Human Service Assistants [5.0]) -[upskill]-> (11-9151.00: Social and Community Service Managers [8.0])
# (21-1093.00: Social and Human Service Assistants [5.0]) -[upskill]-> (21-1021.00: Child, Family, and School Social Workers [6.0])
# (21-1093.00: Social and Human Service Assistants [5.0]) -[upskill]-> (21-1022.00: Healthcare Social Workers [6.0])
# (21-1093.00: Social and Human Service Assistants [5.0]) -[upskill]-> (21-1091.00: Health Education Specialists [6.0])
# (21-1093.00: Social and Human Service Assistants [5.0]) -[upskill]-> (21-1094.00: Community Health Workers [7.0])
# (21-1094.00: Community Health Workers [7.0]) -[upskill]-> (11-9151.00: Social and Community Service Managers [8.0])
# (21-2011.00: Clergy [7.0]) -[upskill]-> (11-9151.00: Social and Community Service Managers [8.0])
teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1112.00: Law Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1121.00: Art, Drama, and Music Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1122.00: Communications Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1124.00: Foreign Language and Literature Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1125.00: History Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1126.00: Philosophy and Religion Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1192.00: Family and Consumer Sciences Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1064.00: Geography Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1081.00: Education Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1082.00: Library Science Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1113.00: Social Work Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1123.00: English Language and Literature Teachers, Postsecondary [8.0])
# (25-1193.00: Recreation and Fitness Studies Teachers, Postsecondary [7.0]) -[upskill]-> (25-1194.00: Career/Technical Education Teachers, Postsecondary [8.0])
# (25-2011.00: Preschool Teachers, Except Special Education [5.0]) -[upskill]-> (25-1021.00: Computer Science Teachers, Postsecondary [7.0])
# (25-2011.00: Preschool Teachers, Except Special Education [5.0]) -[upskill]-> (25-1022.00: Mathematical Science Teachers, Postsecondary [7.0])
# (25-2011.00: Preschool Teachers, Except Special Education [5.0]) -[upskill]-> (25-1031.00: Architecture Teachers, Postsecondary [7.0])
# (25-2011.00: Preschool Teachers, Except Special Education [5.0]) -[upskill]-> (25-1053.00: Environmental Science Teachers, Postsecondary [7.0])
# (25-2011.00: Preschool Teachers, Except Special Education [5.0]) -[upskill]-> (25-1062.00: Area, Ethnic, and Cultural Studies Teachers, Postsecondary [7.0])
# ...
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-1041.00: Aircraft Cargo Handling Supervisors [6.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-1042.00: First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand [7.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-1043.00: First-Line Supervisors of Material-Moving Machine and Vehicle Operators [7.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-3032.00: Heavy and Tractor-Trailer Truck Drivers [6.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-3033.00: Light Truck Drivers [3.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-4011.00: Locomotive Engineers [6.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-5011.00: Sailors and Marine Oilers [3.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-5021.00: Captains, Mates, and Pilots of Water Vessels [7.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-5022.00: Motorboat Operators [7.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-5031.00: Ship Engineers [7.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-6011.00: Bridge and Lock Tenders [3.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-6061.00: Passenger Attendants [3.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-7051.00: Industrial Truck and Tractor Operators [5.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0])
# (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0]) -[upskill]-> (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-2031.00: Engine and Other Machine Assemblers [5.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-4031.00: Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic [6.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-4072.00: Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic [5.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-4081.00: Multiple Machine Tool Setters, Operators, and Tenders, Metal and Plastic [5.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-8091.00: Chemical Plant and System Operators [6.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-9011.00: Chemical Equipment Operators and Tenders [7.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-9023.00: Mixing and Blending Machine Setters, Operators, and Tenders [6.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-9041.00: Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders [5.0])
# (53-7062.04: Recycling and Reclamation Workers [4.0]) -[upskill]-> (51-9193.00: Cooling and Freezing Equipment Operators and Tenders [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-1011.00: First-Line Supervisors of Production and Operating Workers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-2011.00: Aircraft Structure, Surfaces, Rigging, and Systems Assemblers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-2023.00: Electromechanical Equipment Assemblers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-2031.00: Engine and Other Machine Assemblers [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-2092.00: Team Assemblers [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4022.00: Forging Machine Setters, Operators, and Tenders, Metal and Plastic [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4031.00: Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4032.00: Drilling and Boring Machine Tool Setters, Operators, and Tenders, Metal and Plastic [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4033.00: Grinding, Lapping, Polishing, and Buffing Machine Tool Setters, Operators, and Tenders, Metal and Plastic [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4035.00: Milling and Planing Machine Setters, Operators, and Tenders, Metal and Plastic [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4041.00: Machinists [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4051.00: Metal-Refining Furnace Operators and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4061.00: Model Makers, Metal and Plastic [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4062.00: Patternmakers, Metal and Plastic [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4072.00: Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4081.00: Multiple Machine Tool Setters, Operators, and Tenders, Metal and Plastic [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4111.00: Tool and Die Makers [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4121.00: Welders, Cutters, Solderers, and Brazers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4122.00: Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4191.00: Heat Treating Equipment Setters, Operators, and Tenders, Metal and Plastic [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4192.00: Layout Workers, Metal and Plastic [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-4194.00: Tool Grinders, Filers, and Sharpeners [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-6031.00: Sewing Machine Operators [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-6091.00: Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-7011.00: Cabinetmakers and Bench Carpenters [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-7031.00: Model Makers, Wood [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-7042.00: Woodworking Machine Setters, Operators, and Tenders, Except Sawing [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8011.00: Nuclear Power Reactor Operators [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8012.00: Power Distributors and Dispatchers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8013.00: Power Plant Operators [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8013.03: Biomass Plant Technicians [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8091.00: Chemical Plant and System Operators [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8092.00: Gas Plant Operators [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8093.00: Petroleum Pump System Operators, Refinery Operators, and Gaugers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-8099.01: Biofuels Processing Technicians [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9011.00: Chemical Equipment Operators and Tenders [7.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9012.00: Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9021.00: Crushing, Grinding, and Polishing Machine Setters, Operators, and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9023.00: Mixing and Blending Machine Setters, Operators, and Tenders [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9031.00: Cutters and Trimmers, Hand [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9041.00: Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9051.00: Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9161.00: Computer Numerically Controlled Tool Operators [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9162.00: Computer Numerically Controlled Tool Programmers [6.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9193.00: Cooling and Freezing Equipment Operators and Tenders [5.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (51-9196.00: Paper Goods Machine Setters, Operators, and Tenders [4.0])
# (53-7063.00: Machine Feeders and Offbearers [3.0]) -[upskill]-> (53-7062.04: Recycling and Reclamation Workers [4.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (43-5021.00: Couriers and Messengers [5.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-1041.00: Aircraft Cargo Handling Supervisors [6.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-1042.00: First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand [7.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-1043.00: First-Line Supervisors of Material-Moving Machine and Vehicle Operators [7.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-3033.00: Light Truck Drivers [3.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-5011.00: Sailors and Marine Oilers [3.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-7051.00: Industrial Truck and Tractor Operators [5.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-7062.00: Laborers and Freight, Stock, and Material Movers, Hand [2.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0])
# (53-7064.00: Packers and Packagers, Hand [1.0]) -[upskill]-> (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-1011.00: First-Line Supervisors of Office and Administrative Support Workers [8.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-2011.00: Switchboard Operators, Including Answering Service [4.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-3031.00: Bookkeeping, Accounting, and Auditing Clerks [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-3051.00: Payroll and Timekeeping Clerks [7.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-3061.00: Procurement Clerks [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4021.00: Correspondence Clerks [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4051.00: Customer Service Representatives [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4071.00: File Clerks [5.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4151.00: Order Clerks [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4161.00: Human Resources Assistants, Except Payroll and Timekeeping [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-4171.00: Receptionists and Information Clerks [5.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-5051.00: Postal Service Clerks [5.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-5071.00: Shipping, Receiving, and Inventory Clerks [5.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-6011.00: Executive Secretaries and Executive Administrative Assistants [7.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-6014.00: Secretaries and Administrative Assistants, Except Legal, Medical, and Executive [6.0])
# (53-7065.00: Stockers and Order Fillers [3.0]) -[upskill]-> (43-9021.00: Data Entry Keyers [6.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-1042.00: First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-1043.00: First-Line Supervisors of Material-Moving Machine and Vehicle Operators [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-2011.00: Airline Pilots, Copilots, and Flight Engineers [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-5021.00: Captains, Mates, and Pilots of Water Vessels [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-5022.00: Motorboat Operators [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-5031.00: Ship Engineers [7.0])
# (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0]) -[upskill]-> (53-7071.00: Gas Compressor and Gas Pumping Station Operators [7.0])
# (53-7073.00: Wellhead Pumpers [6.0]) -[upskill]-> (53-1042.00: First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand [7.0])
# (53-7073.00: Wellhead Pumpers [6.0]) -[upskill]-> (53-1043.00: First-Line Supervisors of Material-Moving Machine and Vehicle Operators [7.0])
# (53-7073.00: Wellhead Pumpers [6.0]) -[upskill]-> (53-5022.00: Motorboat Operators [7.0])
# (53-7073.00: Wellhead Pumpers [6.0]) -[upskill]-> (53-5031.00: Ship Engineers [7.0])
# (53-7073.00: Wellhead Pumpers [6.0]) -[upskill]-> (53-7071.00: Gas Compressor and Gas Pumping Station Operators [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-1041.00: Aircraft Cargo Handling Supervisors [6.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-1042.00: First-Line Supervisors of Helpers, Laborers, and Material Movers, Hand [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-1043.00: First-Line Supervisors of Material-Moving Machine and Vehicle Operators [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-3032.00: Heavy and Tractor-Trailer Truck Drivers [6.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-4011.00: Locomotive Engineers [6.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-5021.00: Captains, Mates, and Pilots of Water Vessels [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-5022.00: Motorboat Operators [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-5031.00: Ship Engineers [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-7071.00: Gas Compressor and Gas Pumping Station Operators [7.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-7072.00: Pump Operators, Except Wellhead Pumpers [6.0])
# (53-7121.00: Tank Car, Truck, and Ship Loaders [5.0]) -[upskill]-> (53-7073.00: Wellhead Pumpers [6.0])

# %%
# Print relationship
def print_relation(source_id, target_id):
  source_item = sim_final_df.loc[source_id]
  target_item = sim_final_df.loc[target_id]
  print(f"[{source_item['career_pathway']}] ({source_id}: {source_item['Title']} [{source_item[comparison_col]}]) -[upskill]-> ({target_id}: {target_item['Title']} [{target_item[comparison_col]}])")

def print_targets(id, type='source'):
  id_key = (id + "__") if type == 'source' else ("__" + id)

  def check_key(key):
    return key.startswith(id_key) if type == 'source' else key.endswith(id_key)

  results = [(key, value) for key, value in promotions_dict.items() if check_key(key)]
  for key, value in results:
    if type == 'source':
      print_relation(id, value['target_id'])
    else:
      print_relation(value['source_id'], id)

# %%
# Example
print("Source")
print_targets("51-4052.00")

print("Target")
print_targets("51-4052.00", type='target')
# Out:
# Source
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-2011.00: Aircraft Structure, Surfaces, Rigging, and Systems Assemblers [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-2023.00: Electromechanical Equipment Assemblers [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-2031.00: Engine and Other Machine Assemblers [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4022.00: Forging Machine Setters, Operators, and Tenders, Metal and Plastic [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4031.00: Cutting, Punching, and Press Machine Setters, Operators, and Tenders, Metal and Plastic [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4032.00: Drilling and Boring Machine Tool Setters, Operators, and Tenders, Metal and Plastic [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4033.00: Grinding, Lapping, Polishing, and Buffing Machine Tool Setters, Operators, and Tenders, Metal and Plastic [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4035.00: Milling and Planing Machine Setters, Operators, and Tenders, Metal and Plastic [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4041.00: Machinists [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4051.00: Metal-Refining Furnace Operators and Tenders [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4061.00: Model Makers, Metal and Plastic [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4062.00: Patternmakers, Metal and Plastic [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4071.00: Foundry Mold and Coremakers [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4072.00: Molding, Coremaking, and Casting Machine Setters, Operators, and Tenders, Metal and Plastic [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4081.00: Multiple Machine Tool Setters, Operators, and Tenders, Metal and Plastic [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4111.00: Tool and Die Makers [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4121.00: Welders, Cutters, Solderers, and Brazers [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4122.00: Welding, Soldering, and Brazing Machine Setters, Operators, and Tenders [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4191.00: Heat Treating Equipment Setters, Operators, and Tenders, Metal and Plastic [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4192.00: Layout Workers, Metal and Plastic [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-4194.00: Tool Grinders, Filers, and Sharpeners [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-6091.00: Extruding and Forming Machine Setters, Operators, and Tenders, Synthetic and Glass Fibers [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-7011.00: Cabinetmakers and Bench Carpenters [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-7031.00: Model Makers, Wood [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-7032.00: Patternmakers, Wood [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-7042.00: Woodworking Machine Setters, Operators, and Tenders, Except Sawing [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-8091.00: Chemical Plant and System Operators [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9011.00: Chemical Equipment Operators and Tenders [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9012.00: Separating, Filtering, Clarifying, Precipitating, and Still Machine Setters, Operators, and Tenders [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9021.00: Crushing, Grinding, and Polishing Machine Setters, Operators, and Tenders [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9023.00: Mixing and Blending Machine Setters, Operators, and Tenders [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9041.00: Extruding, Forming, Pressing, and Compacting Machine Setters, Operators, and Tenders [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9051.00: Furnace, Kiln, Oven, Drier, and Kettle Operators and Tenders [4.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9161.00: Computer Numerically Controlled Tool Operators [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9162.00: Computer Numerically Controlled Tool Programmers [6.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9193.00: Cooling and Freezing Equipment Operators and Tenders [5.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9195.04: Glass Blowers, Molders, Benders, and Finishers [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (51-9195.05: Potters, Manufacturing [7.0])
# [Production] (51-4052.00: Pourers and Casters, Metal [3.0]) -[upskill]-> (53-7062.04: Recycling and Reclamation Workers [4.0])
# Target
# [Production] (51-2022.00: Electrical and Electronic Equipment Assemblers [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-3091.00: Food and Tobacco Roasting, Baking, and Drying Machine Operators and Tenders [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-4021.00: Extruding and Drawing Machine Setters, Operators, and Tenders, Metal and Plastic [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-4193.00: Plating Machine Setters, Operators, and Tenders, Metal and Plastic [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-9022.00: Grinding and Polishing Workers, Hand [2.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-9032.00: Cutting and Slicing Machine Setters, Operators, and Tenders [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])
# [Production] (51-9192.00: Cleaning, Washing, and Metal Pickling Equipment Operators and Tenders [1.0]) -[upskill]-> (51-4052.00: Pourers and Casters, Metal [3.0])

# %%
# !pip install networkx
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Requirement already satisfied: networkx in /usr/local/lib/python3.9/dist-packages (3.1)

# %%
import networkx as nx
import matplotlib.pyplot as plt

def build_graph_data(dictionary):
  items = list(dictionary.items())
  n = len(items)
  source = [None] * n
  target = [None] * n
  edge = ["upskill"] * n
  for i in range(n):
    key, item = items[i]
    source_id = item['source_id']
    target_id = item['target_id']
    source_item = sim_final_df.loc[source_id]
    target_item = sim_final_df.loc[target_id]
    source[i] = f"{source_id}: {source_item['Title']}"
    target[i] = f"{target_id}: {target_item['Title']}"

  return pd.DataFrame({
      "source": source,
      "target": target,
      "edge": edge
  })

# Build Graph data
def build_graph(dictionary):
  data = build_graph_data(dictionary)
  # create a directed-graph from a dataframe
  graph = nx.from_pandas_edgelist(data, "source", "target", 
    edge_attr=True, create_using=nx.MultiDiGraph())
  return graph

# Print network graph
def plot_graph(graph):
  plt.figure(figsize=(60,60))
  pos = nx.spring_layout(graph)
  nx.draw(graph, with_labels=True, node_color='red', edge_cmap=plt.cm.Blues, pos = pos)
  plt.show()

# %%
graph = build_graph(promotions_dict)
print(graph)
# Out:
# MultiDiGraph with 793 nodes and 5399 edges

# %%
plot_graph(graph)
# Out:
# Output hidden; open in https://colab.research.google.com to view.
